# %%
# %pip install numpy pandas matplotlib seaborn

# %%
2 + 2

# %%
3 * 3

# %%
# Observe that only the last expression(piece of code is being executed)
3 + 3 # 6
3 - 3 # 0
3 * 3 # 9

# %%
# But when we use print, we don't face that issue.
print(3 + 3)  # 6
print(3 * 3)  # 9
